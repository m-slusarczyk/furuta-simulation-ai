# %%
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# Details:  This script is part of the AI Workshop held at LUT (2026).
# Task:     Large Language Models (LLMs)
# Author:   Michal Slusarczyk
# Date:     12.03.2026
#
#+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

import sys
import os
import numpy as np
# add parent directory to find special class
parent_dir = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
from furutaPendulum import FurutaPendulum

studentNumber = None

massArm = 1         # [kg] mass of the arm
massLink = 1        # [kg] mass of the link
lengthArm = 1       # [m] length of the arm
lengthLink = 1      # [m] lengthof the link
width = 0.2         # [m] width of arm / link
gravity = 9.81      # [m/s^2] gravitational acceleration

# CHANGES ARE ONLY NECESSARY BELOW THIS LINE
def ODE1System(t, x, tauA, tauL): # tauA and tauL (both functions) should NOT appear in your ODEs!
    dx = np.zeros(4)
    dx[0] = x[1]
    dx[1] = (-0.5*massLink*lengthArm*lengthLink*np.sin(x[2])*(x[3]**2)
         - massLink*lengthArm*lengthLink*np.cos(x[2])*np.sin(x[2])*x[1]*x[3]
         + 0.5*massLink*lengthArm*lengthLink*gravity*np.sin(x[2])*np.cos(x[2])) \
        / ((1/3)*massArm*lengthArm**2 + massLink*lengthArm**2
           + ((1/12)*massLink*lengthLink**2 + 0.25*massLink*lengthLink**2)*(np.sin(x[2])**2))
    dx[2] = x[3]
    dx[3] = (-massLink*gravity*(lengthLink/2)*np.sin(x[2])
         - massLink*lengthArm*(lengthLink/2)*np.cos(x[2])*np.sin(x[2])*(x[1]**2)
         + massLink*lengthArm*(lengthLink/2)*np.cos(x[2])*dx[1]) \
        / ((1/12)*massLink*lengthLink**2 + 0.25*massLink*lengthLink**2)
    return dx
# CHANGES ARE ONLY NECESSARY ABOVE THIS LINE

pendulum = FurutaPendulum(massArm=massArm, massLink=massLink,
                          lengthArm=lengthArm, lengthLink=lengthLink,
                          width=width, gravity=gravity)
x0 = [0, 0, 0.01, 0]
pendulum.GenerateTrajectory(SystemOfODE1=ODE1System, x0=x0,
                            label='EOMs by LLM', plot=True, TauA=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      12 import numpy as np
#      13 # add parent directory to find special class
# ---> 14 parent_dir = os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))
#      15 if parent_dir not in sys.path:
#      16     sys.path.insert(0, parent_dir)
#
# NameError: name '__file__' is not defined
